# %% [markdown]
# ## Historically Weighted Metrics vs. Acutal Adjusted Metrics from the Tournament

# %%
import sqlite3
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import make_scorer, fbeta_score
from xgboost import XGBClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

conn = sqlite3.connect('/Users/nickospelt/Documents/App_Projects/PGA_Tournament_Winner/Data/PGA_SQL_DB/PGA.db')

# %% [markdown]
# ### Pull Data

# %%
df = pd.read_sql_query("SELECT * FROM METRIC_ANALYSIS", conn)
df = df.dropna()
df
# Out:
#               TOURNAMENT_NAME         PLAYER_NAME      TOURNAMENT_DATE  \
# 0      2024 ZOZO CHAMPIONSHIP     Nico Echavarria  2024-10-24 00:00:00
# 1      2024 ZOZO CHAMPIONSHIP       Justin Thomas  2024-10-24 00:00:00
# 2      2024 ZOZO CHAMPIONSHIP      Max Greyserman  2024-10-24 00:00:00
# 3      2024 ZOZO CHAMPIONSHIP       Rickie Fowler  2024-10-24 00:00:00
# 4      2024 ZOZO CHAMPIONSHIP       Kurt Kitayama  2024-10-24 00:00:00
# ...                       ...                 ...                  ...
# 11673   2017 PGA Championship        Lee Westwood  2017-08-10 00:00:00
# 11674   2017 PGA Championship   Daniel Summerhays  2017-08-10 00:00:00
# 11675   2017 PGA Championship      Russell Henley  2017-08-10 00:00:00
# 11676   2017 PGA Championship  Charles Howell III  2017-08-10 00:00:00
# 11678   2017 PGA Championship      Anirban Lahiri  2017-08-10 00:00:00
#
#        POSITION    FINISH  HL_50_SG_P  HL_100_SG_P  HL_200_SG_P  ADJ_SG_P  \
# 0           1.0       WIN   -0.089891    -0.097941    -0.102004  1.064873
# 1           2.0     TOP 5   -0.699328    -0.664840    -0.551481 -0.195627
# 2           2.0     TOP 5    0.049363     0.111252     0.142483  2.592623
# 3           4.0     TOP 5   -0.111900     0.005633     0.102397  1.905873
# 4           5.0     TOP 5   -0.627745    -0.516313    -0.380011  0.123123
# ...         ...       ...         ...          ...          ...       ...
# 11673      67.0  MADE CUT   -1.000013    -0.876345    -0.812916 -0.859883
# 11674      71.0  MADE CUT   -0.189880    -0.281847    -0.316116 -0.069133
# 11675      71.0  MADE CUT    0.386100     0.348888     0.341597 -1.461133
# 11676      73.0  MADE CUT    0.482900     0.280695     0.148889 -0.608383
# 11678      75.0  MADE CUT    2.096859     2.096859     2.096859 -2.014383
#
#        HL_50_SG_OTT  ...  HL_200_R4_SCR  ADJ_R4_SCR   T12_EARNINGS  \
# 0         -0.209515  ...      -0.357448   -1.428571   13258.800000
# 1          0.559205  ...      -0.006809   -2.428571  119472.142857
# 2          0.941564  ...      -1.284700   -3.428571   66951.750000
# 3         -0.191549  ...       0.197957   -4.428571   51912.750000
# 4          0.294138  ...      -1.556688   -3.428571  108649.714286
# ...             ...  ...            ...         ...            ...
# 11673     -0.258473  ...       0.381093    3.173333   65091.500000
# 11674     -0.624798  ...       2.784587    4.173333   53680.666667
# 11675      0.342063  ...      -0.592993    1.173333  143113.250000
# 11676     -0.463370  ...       1.136779    0.173333   12661.600000
# 11678     -0.494105  ...      -8.973684    6.173333  191400.000000
#
#        T12_FED_EX_PTS  T12_WINS  T12_TOP_5  T12_TOP_10  T12_TOP_20  \
# 0            3.400000       0.0   0.000000    0.000000    0.000000
# 1           44.285714       0.0   0.000000    0.142857    0.142857
# 2           29.250000       0.0   0.000000    0.000000    0.000000
# 3           12.625000       0.0   0.000000    0.000000    0.000000
# 4           32.714286       0.0   0.000000    0.000000    0.142857
# ...               ...       ...        ...         ...         ...
# 11673        0.000000       0.0   0.000000    0.000000    0.250000
# 11674       17.166667       0.0   0.000000    0.166667    0.166667
# 11675       53.500000       0.0   0.166667    0.333333    0.500000
# 11676        6.000000       0.0   0.000000    0.000000    0.000000
# 11678       61.250000       0.0   0.250000    0.250000    0.250000
#
#        T12_MADE_CUTS  T12_APPERANCES
# 0           0.400000               5
# 1           0.428571               7
# 2           0.500000               4
# 3           0.750000               8
# 4           0.857143               7
# ...              ...             ...
# 11673       1.000000               4
# 11674       0.833333               6
# 11675       1.000000               6
# 11676       0.666667               3
# 11678       0.250000               4
#
# [4797 rows x 45 columns]

# %% [markdown]
# ### Assess Correlation between Historical Metrics and Actual Metrics for the Tournament

# %%
features = ['SG_P', 'SG_OTT', 'SG_APR', 'SG_ATG', 'R1_SCR', 'R2_SCR', 'R3_SCR', 'R4_SCR']

for feature in features:
    ADJ = "ADJ_" + feature
    HL_50 = "HL_50_" + feature
    HL_100 = "HL_100_" + feature
    HL_200 = "HL_200_" + feature

    hl_50_corr, hl_50_p_value = pearsonr(df[HL_50], df[ADJ])
    hl_100_corr, hl_100_p_value = pearsonr(df[HL_100], df[ADJ])
    hl_200_corr, hl_200_p_value = pearsonr(df[HL_200], df[ADJ])

    adj_corr, adj_p_value = pearsonr(df[ADJ], df['POSITION'])
    hl_50_pos_corr, hl_50_pos_p_value = pearsonr(df[HL_50], df['POSITION'])
    hl_100_pos_corr, hl_100_pos_p_value = pearsonr(df[HL_100], df['POSITION'])
    hl_200_pos_corr, hl_200_pos_p_value = pearsonr(df[HL_200], df['POSITION'])

    print(feature)
    print(f"{HL_50} vs {ADJ}; Correlation: [{hl_50_corr}], p-value: [{hl_50_p_value}]")
    print(f"{HL_100} vs {ADJ}; Correlation: [{hl_100_corr}], p-value: [{hl_100_p_value}]")
    print(f"{HL_200} vs {ADJ}; Correlation: [{hl_200_corr}], p-value: [{hl_200_p_value}]\n")
    print(f"{ADJ} vs POSITION; Correlation: [{adj_corr}], p-value: [{adj_p_value}]")
    print(f"{HL_50} vs POSITION; Correlation: [{hl_50_pos_corr}], p-value: [{hl_50_pos_p_value}]")
    print(f"{HL_100} vs POSITION; Correlation: [{hl_100_pos_corr}], p-value: [{hl_100_pos_p_value}]")
    print(f"{HL_200} vs POSITION; Correlation: [{hl_200_pos_corr}], p-value: [{hl_200_pos_p_value}]\n\n")
# Out:
# SG_P
# HL_50_SG_P vs ADJ_SG_P; Correlation: [0.1146843074047269], p-value: [1.6216863886937704e-15]
# HL_100_SG_P vs ADJ_SG_P; Correlation: [0.12983426707187978], p-value: [1.7441727810127896e-19]
# HL_200_SG_P vs ADJ_SG_P; Correlation: [0.14070209076649184], p-value: [1.2272767421160192e-22]
#
# ADJ_SG_P vs POSITION; Correlation: [-0.4433877585947892], p-value: [3.146889475110575e-230]
# HL_50_SG_P vs POSITION; Correlation: [-0.010008353098144787], p-value: [0.4882976116037048]
# HL_100_SG_P vs POSITION; Correlation: [-0.012867008128795326], p-value: [0.37294071485767805]
# HL_200_SG_P vs POSITION; Correlation: [-0.015382418331324905], p-value: [0.2867956245293225]
#
#
# SG_OTT
# HL_50_SG_OTT vs ADJ_SG_OTT; Correlation: [0.3290564172938355], p-value: [1.6540367828909302e-121]
# HL_100_SG_OTT vs ADJ_SG_OTT; Correlation: [0.35382115562301303], p-value: [1.7823781665556674e-141]
# HL_200_SG_OTT vs ADJ_SG_OTT; Correlation: [0.3748256982260952], p-value: [7.055724187190828e-160]
#
# ADJ_SG_OTT vs POSITION; Correlation: [-0.3915963191453975], p-value: [1.3841190936481496e-175]
# HL_50_SG_OTT vs POSITION; Correlation: [-0.1526144530593782], p-value: [2.1680531585768787e-26]
# HL_100_SG_OTT vs POSITION; Correlation: [-0.16615677806642642], p-value: [4.869612478052998e-31]
# HL_200_SG_OTT vs POSITION; Correlation: [-0.17549072441903613], p-value: [1.753208678760812e-34]
#
#
# SG_APR
# HL_50_SG_APR vs ADJ_SG_APR; Correlation: [0.17023442774880024], p-value: [1.6117592756149435e-32]
# HL_100_SG_APR vs ADJ_SG_APR; Correlation: [0.17932043221167546], p-value: [5.939663042866137e-36]
# HL_200_SG_APR vs ADJ_SG_APR; Correlation: [0.1886978856119878], p-value: [1.0777988054132071e-39]
#
# ADJ_SG_APR vs POSITION; Correlation: [-0.5114171555691456], p-value: [4.52723e-318]
# HL_50_SG_APR vs POSITION; Correlation: [-0.10642961275506832], p-value: [1.463520282120004e-13]
# HL_100_SG_APR vs POSITION; Correlation: [-0.112441934658238], p-value: [5.695210724624276e-15]
# HL_200_SG_APR vs POSITION; Correlation: [-0.1170777569745423], p-value: [4.128733930066059e-16]
#
#
# SG_ATG
# HL_50_SG_ATG vs ADJ_SG_ATG; Correlation: [0.11064575824436482], p-value: [1.53026078693182e-14]
# HL_100_SG_ATG vs ADJ_SG_ATG; Correlation: [0.1216170752842115], p-value: [2.8527641003548024e-17]
# HL_200_SG_ATG vs ADJ_SG_ATG; Correlation: [0.1311425326666381], p-value: [7.510638265250934e-20]
#
# ADJ_SG_ATG vs POSITION; Correlation: [-0.33233821513504874], p-value: [4.750055394942482e-124]
# HL_50_SG_ATG vs POSITION; Correlation: [-0.051832877165169426], p-value: [0.0003288517691315267]
# HL_100_SG_ATG vs POSITION; Correlation: [-0.05260955292787654], p-value: [0.000267046435328789]
# HL_200_SG_ATG vs POSITION; Correlation: [-0.053416041070127686], p-value: [0.00021450318747653563]
#
#
# R1_SCR
# HL_50_R1_SCR vs ADJ_R1_SCR; Correlation: [0.058251983132472734], p-value: [5.4154984046444696e-05]
# HL_100_R1_SCR vs ADJ_R1_SCR; Correlation: [0.059653181044106184], p-value: [3.5618244706761436e-05]
# HL_200_R1_SCR vs ADJ_R1_SCR; Correlation: [0.06138875469490232], p-value: [2.0931699765323825e-05]
#
# ADJ_R1_SCR vs POSITION; Correlation: [0.3363565469761193], p-value: [3.3232079931413924e-127]
# HL_50_R1_SCR vs POSITION; Correlation: [0.1299581483025076], p-value: [1.6110159017891233e-19]
# HL_100_R1_SCR vs POSITION; Correlation: [0.14576927129498513], p-value: [3.394431569120308e-24]
# HL_200_R1_SCR vs POSITION; Correlation: [0.15897167939029577], p-value: [1.6026406306848494e-28]
#
#
# R2_SCR
# HL_50_R2_SCR vs ADJ_R2_SCR; Correlation: [0.026436716193965978], p-value: [0.06712147947134621]
# HL_100_R2_SCR vs ADJ_R2_SCR; Correlation: [0.038316778372495766], p-value: [0.007951611894720136]
# HL_200_R2_SCR vs ADJ_R2_SCR; Correlation: [0.0510007450842493], p-value: [0.00040977044696591]
#
# ADJ_R2_SCR vs POSITION; Correlation: [0.285744734510777], p-value: [8.254756721324587e-91]
# HL_50_R2_SCR vs POSITION; Correlation: [0.13016808850255918], p-value: [1.4079090534702858e-19]
# HL_100_R2_SCR vs POSITION; Correlation: [0.15013350604727987], p-value: [1.391452769202744e-25]
# HL_200_R2_SCR vs POSITION; Correlation: [0.16945155087820327], p-value: [3.1217141056070935e-32]
#
#
# R3_SCR
# HL_50_R3_SCR vs ADJ_R3_SCR; Correlation: [0.07551339993022217], p-value: [1.639156425808504e-07]
# HL_100_R3_SCR vs ADJ_R3_SCR; Correlation: [0.08685111436332035], p-value: [1.6894158434044209e-09]
# HL_200_R3_SCR vs ADJ_R3_SCR; Correlation: [0.0957813884881955], p-value: [2.9828802529670896e-11]
#
# ADJ_R3_SCR vs POSITION; Correlation: [0.5623441080219769], p-value: [0.0]
# HL_50_R3_SCR vs POSITION; Correlation: [0.12754896797920584], p-value: [7.445213954613572e-19]
# HL_100_R3_SCR vs POSITION; Correlation: [0.13537416386072948], p-value: [4.6415874200814664e-21]
# HL_200_R3_SCR vs POSITION; Correlation: [0.14291445110743606], p-value: [2.6035476858991168e-23]
#
#
# R4_SCR
# HL_50_R4_SCR vs ADJ_R4_SCR; Correlation: [0.07081675038865626], p-value: [9.12245076485054e-07]
# HL_100_R4_SCR vs ADJ_R4_SCR; Correlation: [0.07998919285324699], p-value: [2.8973616040990835e-08]
# HL_200_R4_SCR vs ADJ_R4_SCR; Correlation: [0.08785393890489895], p-value: [1.0943823910908093e-09]
#
# ADJ_R4_SCR vs POSITION; Correlation: [0.6139444347564241], p-value: [0.0]
# HL_50_R4_SCR vs POSITION; Correlation: [0.10017440834313285], p-value: [3.5556019549521593e-12]
# HL_100_R4_SCR vs POSITION; Correlation: [0.11582142123857621], p-value: [8.496054051582579e-16]
# HL_200_R4_SCR vs POSITION; Correlation: [0.13007987456846193], p-value: [1.4899706660401297e-19]

# %% [markdown]
# - __First 3 Rows__: Looking how the exponentially weighted average metric relate to the actual adjust values observed in the tournament
# - __Last 4 Rows__: How the adjusted value and historical values relate to the final position in the tournament
# <br><br>
# - All adjusted metrics strongly correlate to a players finish in the tournament
# - However, like suspected, simply taking the exponentially weighted average of the adjust metrics doesn't prove to be a great estimator of what the strokes gained or score values will be (Not very significant correlation)
# - Need to improve the quality of these historical estimations
